# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance

# %%
df = pd.read_csv("../data/processed/wine_processed.csv")

X = df.drop("quality", axis=1)
y = df["quality"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
rf = RandomForestClassifier(random_state=42)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance
# Out:
#                  Feature  Importance
# 10               alcohol    0.154001
# 9              sulphates    0.117177
# 6   total sulfur dioxide    0.101317
# 1       volatile acidity    0.098642
# 7                density    0.087199
# 4              chlorides    0.080849
# 2            citric acid    0.078817
# 8                     pH    0.074424
# 0          fixed acidity    0.070513
# 3         residual sugar    0.070100
# 5    free sulfur dioxide    0.066962

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=importance,
    x="Importance",
    y="Feature",
    hue="Feature",
    legend=False,
    palette="viridis"
)

plt.title("Random Forest Feature Importance")

plt.show()

# %%
result = permutation_importance(
    rf,
    X_test,
    y_test,
    n_repeats=10,
    random_state=42
)

perm = pd.DataFrame({
    "Feature": X.columns,
    "Importance": result.importances_mean
})

perm = perm.sort_values(
    by="Importance",
    ascending=False
)

perm
# Out:
#                  Feature  Importance
# 10               alcohol    0.073039
# 9              sulphates    0.033824
# 6   total sulfur dioxide    0.016667
# 8                     pH    0.012255
# 0          fixed acidity    0.010784
# 1       volatile acidity    0.008333
# 7                density    0.002451
# 5    free sulfur dioxide    0.001471
# 2            citric acid   -0.003922
# 4              chlorides   -0.007843
# 3         residual sugar   -0.008333

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=perm,
    x="Importance",
    y="Feature",
    hue="Feature",
    legend=False,
    palette="magma"
)

plt.title("Permutation Feature Importance")

plt.show()

# %%
importance.to_csv(
    "../reports/results/feature_importance.csv",
    index=False
)

perm.to_csv(
    "../reports/results/permutation_importance.csv",
    index=False
)

print("Explainability results saved successfully!")
# Out:
# Explainability results saved successfully!
